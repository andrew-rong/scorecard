# %%
import pandas as pd
import openpyxl
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split

# %%
# Load Excel file (skip header rows used for titles)
df = pd.read_excel("historical-cpi-u-202602.xlsx", skiprows=4)

# Rename columns
df.columns = [
    "Indent", "Year", "Jan", "Feb", "Mar", "Apr",
    "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"
]

# Remove unnecessary column
df = df.drop(columns=["Indent"])

df_long = df.melt(
    id_vars="Year",
    var_name="Month",
    value_name="CPI"
)

print(df_long.head())

# Save to new file
df_long.to_csv("cpi_monthly_long_format.csv", index=False)
# Out:
#    Year Month   CPI
# 0  1913   Jan   9.8
# 1  1914   Jan  10.0
# 2  1915   Jan  10.1
# 3  1916   Jan  10.4
# 4  1917   Jan  11.7

# %%
df = pd.read_excel('historical-cpi-u-202602.xlsx', header=None)
data = df.iloc[5:119].copy()
data.columns = ['indent', 'Year', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
data = data[['Year', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']].copy()
data['Year'] = data['Year'].astype(int)

months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
month_order = {m: i+1 for i, m in enumerate(months)}

melted = data.melt(id_vars='Year', value_vars=months, var_name='Month', value_name='CPI')
melted = melted.sort_values(['Year']).reset_index(drop=True)
melted['CPI'] = pd.to_numeric(melted['CPI'].replace({'–': None, '-': None}), errors='coerce')
melted = melted.dropna(subset=['CPI'])
melted['Month-Year'] = melted['Month'] + '-' + melted['Year'].astype(str)
melted = melted[['Month-Year', 'CPI']].reset_index(drop=True)
melted.columns = ['Month-Year', 'CPI']

melted.to_excel('historical-cpi-u-reorganized.xlsx', index=False)

# %%
df = pd.read_excel('historical-cpi-u-reorganized.xlsx')
df['Change%'] = df['CPI'].pct_change()*100
df = df.dropna()

# %%
df
# Out:
#      Month-Year      CPI   Change%
# 1      Feb-1913    9.800  0.000000
# 2      May-1913    9.700 -1.020408
# 3      Jun-1913    9.800  1.030928
# 4      Dec-1913   10.000  2.040816
# 5      Sep-1913   10.000  0.000000
# ...         ...      ...       ...
# 1352   Jan-2025  317.671 -0.442206
# 1353   Mar-2025  319.799  0.669875
# 1354   Apr-2025  320.795  0.311446
# 1355   Feb-2026  326.785  1.867236
# 1356   Jan-2026  325.252 -0.469116
#
# [1356 rows x 3 columns]

# %%
plt.hist(df['Change%'], bins=100, color='#108A99', edgecolor='black')
plt.title("% Change of Monthly CPI")
plt.xlabel("CPI Change")
plt.ylabel("Frequency")
plt.show()

# %%
df.nlargest(n=20, columns=['Change%'])
# Out:
#      Month-Year      CPI    Change%
# 48     Oct-1917   13.500  26.168224
# 84     Apr-1920   20.300  25.308642
# 408    Aug-1947   22.500  24.309392
# 72     Jul-1919   17.400  22.535211
# 60     May-1918   14.500  20.833333
# 396    Nov-1946   21.300  19.662921
# 405    Dec-1946   21.500  17.486339
# 804    Apr-1980   81.000  17.221418
# 348    Sep-1942   16.500  15.384615
# 80     Dec-1919   18.900  15.243902
# 63     Oct-1918   16.000  14.285714
# 756    Dec-1976   58.200  11.708253
# 738    Dec-1974   51.900  11.373391
# 1308   Sep-2022  296.808  11.141567
# 398    Aug-1946   20.200  10.989011
# 402    Sep-1946   20.400  10.869565
# 768    Oct-1977   61.600  10.791367
# 336    Nov-1941   15.400  10.000000
# 344    Dec-1941   15.500   9.929078
# 720    Aug-1973   45.100   9.732360

# %%
df.nsmallest(n=20, columns=['Change%'])
# Out:
#     Month-Year   CPI    Change%
# 397   Jan-1946  18.2 -14.553991
# 406   May-1946  18.5 -13.953488
# 71    Apr-1918  14.2 -12.883436
# 83    Feb-1919  16.2 -12.432432
# 96    Apr-1921  18.1 -12.135922
# 216   Sep-1931  15.0 -11.242604
# 81    Jun-1919  16.9 -10.582011
# 39    Mar-1916  10.5  -9.482759
# 67    Mar-1918  14.0  -9.090909
# 807   Jan-1980  77.8  -9.005848
# 75    Jan-1919  16.5  -8.839779
# 737   Jan-1974  46.6  -8.806262
# 58    Jan-1917  11.7  -8.593750
# 403   Jun-1946  18.7  -8.333333
# 794   Apr-1979  70.6  -7.953064
# 53    Mar-1917  12.0  -7.692308
# 784   Jan-1978  62.5  -7.680945
# 79    Mar-1919  16.4  -7.344633
# 401   Apr-1946  18.4  -7.070707
# 418   Feb-1947  21.5  -6.926407

# %%
import yfinance as yf
rets = yf.download(tickers='SPX', start="1990-12-31", interval='1mo')['Close']
# Out:
# $SPX: possibly delisted; no price data found  (1mo 1990-12-31 -> 2026-03-26)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPX']: possibly delisted; no price data found  (1mo 1990-12-31 -> 2026-03-26)

# %%
rets
# Out:
# Empty DataFrame
# Columns: [SPX]
# Index: []
